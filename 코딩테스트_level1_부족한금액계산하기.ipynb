# %% [markdown]
# # 부족한 금액 계산하기

# %% [markdown]
# ![스크린샷 2023-03-20 오전 9.49.04.png](data:image/png;base64,...)

# %% [markdown]
# my Code

# %%
def solution(price, money, count):
    cnt_price = 0
    
    for i in range(1, count+1):
        cnt_price += i * price
    return abs(cnt_price - money)

# %%
solution(3,20,4)
# Out:
# 10

# %% [markdown]
# Solution

# %%
def solution(price, money, count):

    for i in range(1,count+1):
        money -= price*i
    if money < 0:
        money = abs(money)
    else:
        money = 0 

    return money
