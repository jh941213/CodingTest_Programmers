# %% [markdown]
# 레벨2 JadenCase

# %% [markdown]
# ![스크린샷 2023-02-27 오전 9.39.16.png](data:image/png;base64,...)

# %%
def solution(s):
    s = s.lower()
    s = s.split(' ')
    answer = []
    for i in s:
        answer.append(i.capitalize())
    answer = ' '.join(answer)
    return answer

# %%
solution("for the last week")
# Out:
# 'For The Last Week'
