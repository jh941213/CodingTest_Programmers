# %% [markdown]
# # Lv.1 문자열 다루기 기본

# %% [markdown]
# ![스크린샷 2023-03-16 오후 12.26.06.png](data:image/png;base64,...)

# %%
def solution(s):
    
	return s.isdigit() and len(s) in (4,6) #숫자인지 확인 길이가 4~6이라면

# %%
solution('a234')
# Out:
# False
