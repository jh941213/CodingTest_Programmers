# %% [markdown]
# 코딩테스트 짝수와 홀수 레벨 1
#
#
# ![스크린샷 2023-01-24 오후 2.01.52.png](data:image/png;base64,...)

# %%
def solution(num):
    answer = ''
    if num %2== 0:
        answer += "Even"
    else:
        answer += "Odd"
    return answer
