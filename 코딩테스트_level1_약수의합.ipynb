# %% [markdown]
# ## 코딩테스트 약수의 합

# %% [markdown]
# ![스크린샷 2023-01-24 오후 2.13.02.png](data:image/png;base64,...)

# %%
def solution(n):
    answer = []
    for i in range(1,n+1):
        if n%i ==0:
            answer.append(i)
           # 0 부터 시작하는걸 주의하자 항상  
    return sum(answer)

# %% [markdown]
# ![스크린샷 2023-01-24 오후 2.13.45.png](data:image/png;base64,...)
