# %% [markdown]
# ## 하샤드 수

# %% [markdown]
# ![스크린샷 2023-01-27 오전 10.06.00.png](data:image/png;base64,...)

# %%
def solution(x):
    answer=[]
    tot=0
    for i in str(x):
        answer.append(i)
    answer=sum(list(map(int, answer)))
    if x%answer==0:
        return True
    else:
        return False

# %%
solution(13)
# Out:
# False

# %% [markdown]
# Solution
