# %% [markdown]
# 레벨 1 가운데 글자 가져오기

# %% [markdown]
# ![스크린샷 2023-02-10 오전 9.33.35.png](data:image/png;base64,...)

# %%
def solution(s):
    sl1=len(s)//2
    sl2=(len(s)//2)-1
    sl3=(len(s)//2)+1
    if len(s) % 2==1:
        return s[sl1:sl1+1]
    else:
        return s[sl2:sl3]

# %%
solution('abcde')
# Out:
# 'c'
