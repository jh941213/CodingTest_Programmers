# %% [markdown]
# ## 프로그래머스 레벨 0 자연수 뒤집어 배열로 만들기

# %% [markdown]
# ![스크린샷 2023-01-25 오전 9.48.08.png](data:image/png;base64,...)

# %%
def solution(n):
    answer = []
    for i in str(n)[::-1]:
        answer.append(int(i))
    return answer

# %%
solution(1234)
# Out:
# ['4', '3', '2', '1']

# %% [markdown]
# ![스크린샷 2023-01-25 오전 9.50.22.png](data:image/png;base64,...)
