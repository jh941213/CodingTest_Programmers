# %% [markdown]
# 레벨 1 수박수박수

# %% [markdown]
# ![스크린샷 2023-02-10 오전 9.47.56.png](data:image/png;base64,...)

# %%
def solution(n):
    answer = '수박'
    
    if n%2==1:
        return answer*(n//2) + answer[:1]
    else:
        return answer*(n//2)

# %%
solution(3)
# Out:
# '수박수'
