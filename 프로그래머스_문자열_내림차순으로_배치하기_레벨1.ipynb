# %% [markdown]
# # Lv.1 문자열 내림차순으로 배치하기

# %% [markdown]
# ![스크린샷 2023-03-15 오전 9.44.47.png](data:image/png;base64,...)

# %%
def solution(s):
    answer = s[::-1]
    return answer

# %%
solution('Zbcdefg')
# Out:
# 'gfedcbZ'
