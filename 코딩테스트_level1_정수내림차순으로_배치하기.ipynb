# %% [markdown]
# ## 정수 내림차순으로 배치하기

# %% [markdown]
# ![스크린샷 2023-01-27 오전 9.55.53.png](data:image/png;base64,...)

# %%
def solution(n):
    answer = []
    for i in str(n):
        answer.append(i)
    answer.sort(reverse=True)
    answer=int(''.join(answer))
    return answer

# %%
solution(1235)
# Out:
# 5321

# %% [markdown]
# Solution
