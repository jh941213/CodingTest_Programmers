# %% [markdown]
# ## 핸드폰 번호 가리기

# %% [markdown]
# ![스크린샷 2023-02-01 오전 9.39.33.png](data:image/png;base64,...)

# %%
def solution(phone_number):
    answer = ''
    phone_number[-4]
    return answer

# %%
solution('010-2920-4946')
# Out:
# [5, 10]

# %% [markdown]
# Solution

# %%
def solution(phone_number):
    answer = ''
    
    phone_number_len = len(phone_number)
    
    answer = '*' * (phone_number_len - 4)
    
    answer += phone_number[-4:]
    
    return answer

# %%
a
# Out:
# '*'
