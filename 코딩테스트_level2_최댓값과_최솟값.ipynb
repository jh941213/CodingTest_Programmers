# %% [markdown]
# 레벨2 최댓값과 최솟값

# %% [markdown]
# ![스크린샷 2023-02-27 오전 9.22.59.png](data:image/png;base64,...)

# %%
def solution(s):
    total = ''
    s = s.split(' ')
    s = list(map(int, s))
    s.sort()
    total = str(s[0])+' '+str(s[-1])
    
    return total

# %%
solution('-1 -2 -3 -4')
# Out:
# '-4 -1'
