# %% [markdown]
# ## 프로그래머스 레벨 0 자연수 뒤집어 배열로 만들기

# %% [markdown]
# ![스크린샷 2023-01-25 오전 10.02.20.png](data:image/png;base64,...)

# %%
def solution(n):
    sqrt = n**(1/2)
    # 파이썬에서 **(1/2)제곱근을 나타낸다고 한다.
    if sqrt % 1 == 0:
        return (sqrt+1)**2
    else: return -1

# %%
solution(144)
# Out:
# 169.0
