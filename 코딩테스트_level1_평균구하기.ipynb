# %% [markdown]
# ## 프로그래머스 레벨 0 평균 구하기

# %% [markdown]
# ![스크린샷 2023-01-25 오전 9.44.24.png](data:image/png;base64,...)

# %%
def solution(arr):
    answer = 0
    for i in arr:
        answer +=i
    answer = answer/len(arr)
    return answer

# %% [markdown]
# ![스크린샷 2023-01-25 오전 9.44.34.png](data:image/png;base64,...)
